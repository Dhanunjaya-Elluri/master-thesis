# %%
import sys
sys.path.append('../approximations')
import numpy as np
from pa_approx import PAA

# %%
X = np.random.randn(100)
paa = PAA(window_size=10)
paa.fit(X)
paa_segments = paa.transform(X)
print(paa_segments)

paa.plot(X)
# Out:
# [-0.14931831  0.47251835 -0.18592457  0.39589058 -0.37390908  0.08620333
#  -0.05822415  0.41962204 -0.48091792 -0.18949557]
