# %%
import sys
sys.path.append('../master-thesis')
import numpy as np
from approximations.pa_approx import PAA

# %%
X = np.random.randn(100)
paa = PAA(window_size=10)
paa.fit(X)
paa_segments = paa.transform(X)
print(paa_segments)

paa.plot(X)
# Out:
# [ 0.11165144 -0.16075036  0.27613599  0.25856338 -0.11158908 -0.16249012
#  -0.23624618 -0.3066048  -0.17101989 -0.36814789]
